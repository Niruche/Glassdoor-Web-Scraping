# %% [markdown]
# # Topic Modelling template

# %%
import pandas as pd

import numpy as np

import spacy
nlp = spacy.load('en_core_web_sm')

import gensim
from gensim import corpora

from datetime import datetime as dt

import pyLDAvis.gensim

from operator import itemgetter

# %%
df = pd.read_csv('glassdoor_full_dataset.csv')
df['date'] = pd.to_datetime(df.date)
df.head()
# Out:
#         date  star                                      subject  \
# 0 2019-11-04     5  Big dynamic company with many opportunities
# 1 2020-01-20     5                          Great Vacation Work
# 2 2020-01-20     4                                Great company
# 3 2020-01-16     3                            Something Helpful
# 4 2020-01-15     3                            One day probation
#
#                                       pros  \
# 0     Fast grows up if you are hard worker
# 1  Lots of shifts and flexibility of hours
# 2      Great training, benefits and salary
# 3        The worst thing is loss of bonus.
# 4           Lot to learn, busy, new people
#
#                                                 cons  \
# 0             unstable rota and early morning shifts
# 1                   Management are lax on food waste
# 2                              Nothing to say so far
# 3  New management created silly rules and people ...
# 4                                          Very busy
#
#                                               advice        location  \
# 0                                                NaN          London
# 1                                                NaN         Gatwick
# 2                                                NaN             NaN
# 3  Respect your staff more.They are amazing hard ...          London
# 4                       Be more patient with newbies   Palmers Green
#
#           clean_member_type  \
# 0              Team Leader
# 1              Team Member
# 2              Team Leader
# 3   Production Team Member
# 4            Kitchen Staff
#
#                                               tenure   employee_status  \
# 0  I have been working at Pret A Manger full-time...  Current Employee
# 1  I worked at Pret A Manger full-time for less t...   Former Employee
# 2     I have been working at Pret A Manger full-time  Current Employee
# 3  I worked at Pret A Manger full-time for more t...   Former Employee
# 4  I worked at Pret A Manger full-time for less t...   Former Employee
#
#   recommend   outlook       ceo Career Opportunities  \
# 0       NaN       NaN       NaN             Positive
# 1       NaN       NaN       NaN             Positive
# 2       NaN       NaN       NaN             Positive
# 3      True  positive  positive             Negative
# 4       NaN       NaN       NaN              Neutral
#
#   Compensation and Benefits Culture & Values Senior Management  \
# 0                  Positive         Positive          Positive
# 1                  Positive         Positive          Positive
# 2                  Positive         Positive          Positive
# 3                  Negative         Negative           Neutral
# 4                   Neutral          Neutral           Neutral
#
#   Work/Life Balance star_group
# 0           Neutral   Positive
# 1          Positive   Positive
# 2           Neutral   Positive
# 3          Negative    Neutral
# 4           Neutral    Neutral

# %% [markdown]
# ## Spacy 101

# %%
#create token #spacy 101 - https://spacy.io/usage/spacy-101 #%%time

df['pro_tokens'] = df.pros.map(lambda x: nlp(x))
df['con_tokens'] = df.cons.map(lambda x: nlp(x))

# %%
df.head()
# Out:
#         date  star                                      subject  \
# 0 2019-11-04     5  Big dynamic company with many opportunities
# 1 2020-01-20     5                          Great Vacation Work
# 2 2020-01-20     4                                Great company
# 3 2020-01-16     3                            Something Helpful
# 4 2020-01-15     3                            One day probation
#
#                                       pros  \
# 0     Fast grows up if you are hard worker
# 1  Lots of shifts and flexibility of hours
# 2      Great training, benefits and salary
# 3        The worst thing is loss of bonus.
# 4           Lot to learn, busy, new people
#
#                                                 cons  \
# 0             unstable rota and early morning shifts
# 1                   Management are lax on food waste
# 2                              Nothing to say so far
# 3  New management created silly rules and people ...
# 4                                          Very busy
#
#                                               advice        location  \
# 0                                                NaN          London
# 1                                                NaN         Gatwick
# 2                                                NaN             NaN
# 3  Respect your staff more.They are amazing hard ...          London
# 4                       Be more patient with newbies   Palmers Green
#
#           clean_member_type  \
# 0              Team Leader
# 1              Team Member
# 2              Team Leader
# 3   Production Team Member
# 4            Kitchen Staff
#
#                                               tenure   employee_status  \
# 0  I have been working at Pret A Manger full-time...  Current Employee
# 1  I worked at Pret A Manger full-time for less t...   Former Employee
# 2     I have been working at Pret A Manger full-time  Current Employee
# 3  I worked at Pret A Manger full-time for more t...   Former Employee
# 4  I worked at Pret A Manger full-time for less t...   Former Employee
#
#                          ...                           outlook       ceo  \
# 0                        ...                               NaN       NaN
# 1                        ...                               NaN       NaN
# 2                        ...                               NaN       NaN
# 3                        ...                          positive  positive
# 4                        ...                               NaN       NaN
#
#   Career Opportunities Compensation and Benefits Culture & Values  \
# 0             Positive                  Positive         Positive
# 1             Positive                  Positive         Positive
# 2             Positive                  Positive         Positive
# 3             Negative                  Negative         Negative
# 4              Neutral                   Neutral          Neutral
#
#   Senior Management Work/Life Balance star_group  \
# 0          Positive           Neutral   Positive
# 1          Positive          Positive   Positive
# 2          Positive           Neutral   Positive
# 3           Neutral          Negative    Neutral
# 4           Neutral           Neutral    Neutral
#
#                                         pro_tokens  \
# 0    (Fast, grows, up, if, you, are, hard, worker)
# 1  (Lots, of, shifts, and, flexibility, of, hours)
# 2      (Great, training, ,, benefits, and, salary)
# 3      (The, worst, thing, is, loss, of, bonus, .)
# 4        (Lot, to, learn, ,, busy, ,, new, people)
#
#                                           con_tokens
# 0      (unstable, rota, and, early, morning, shifts)
# 1            (Management, are, lax, on, food, waste)
# 2                        (Nothing, to, say, so, far)
# 3  (New, management, created, silly, rules, and, ...
# 4                                       (Very, busy)
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Clean token column

# %%
def text_cleaner(tokens, root_word = True):
    
    clean_token = []
    
    for token in tokens:
        if token.is_stop == False:
            if (token.pos_ == "VERB") or  (token.pos_ == "NOUN") or (token.pos_ == "ADJ") or (token.pos_ == "ADV"):
                if root_word == True:
                    clean_token.append(token.lemma_)
                else:
                    clean_token.append(token.lower_)
    return clean_token

# %%
#create new column with the above function
df['pro_clean_token'] = df.pro_tokens.map(text_cleaner)
df['con_clean_token'] = df.con_tokens.map(text_cleaner)

# %%
df.head()
# Out:
#         date  star                                      subject  \
# 0 2019-11-04     5  Big dynamic company with many opportunities
# 1 2020-01-20     5                          Great Vacation Work
# 2 2020-01-20     4                                Great company
# 3 2020-01-16     3                            Something Helpful
# 4 2020-01-15     3                            One day probation
#
#                                       pros  \
# 0     Fast grows up if you are hard worker
# 1  Lots of shifts and flexibility of hours
# 2      Great training, benefits and salary
# 3        The worst thing is loss of bonus.
# 4           Lot to learn, busy, new people
#
#                                                 cons  \
# 0             unstable rota and early morning shifts
# 1                   Management are lax on food waste
# 2                              Nothing to say so far
# 3  New management created silly rules and people ...
# 4                                          Very busy
#
#                                               advice        location  \
# 0                                                NaN          London
# 1                                                NaN         Gatwick
# 2                                                NaN             NaN
# 3  Respect your staff more.They are amazing hard ...          London
# 4                       Be more patient with newbies   Palmers Green
#
#           clean_member_type  \
# 0              Team Leader
# 1              Team Member
# 2              Team Leader
# 3   Production Team Member
# 4            Kitchen Staff
#
#                                               tenure   employee_status  \
# 0  I have been working at Pret A Manger full-time...  Current Employee
# 1  I worked at Pret A Manger full-time for less t...   Former Employee
# 2     I have been working at Pret A Manger full-time  Current Employee
# 3  I worked at Pret A Manger full-time for more t...   Former Employee
# 4  I worked at Pret A Manger full-time for less t...   Former Employee
#
#                          ...                         Career Opportunities  \
# 0                        ...                                     Positive
# 1                        ...                                     Positive
# 2                        ...                                     Positive
# 3                        ...                                     Negative
# 4                        ...                                      Neutral
#
#   Compensation and Benefits Culture & Values Senior Management  \
# 0                  Positive         Positive          Positive
# 1                  Positive         Positive          Positive
# 2                  Positive         Positive          Positive
# 3                  Negative         Negative           Neutral
# 4                   Neutral          Neutral           Neutral
#
#   Work/Life Balance star_group  \
# 0           Neutral   Positive
# 1          Positive   Positive
# 2           Neutral   Positive
# 3          Negative    Neutral
# 4           Neutral    Neutral
#
#                                         pro_tokens  \
# 0    (Fast, grows, up, if, you, are, hard, worker)
# 1  (Lots, of, shifts, and, flexibility, of, hours)
# 2      (Great, training, ,, benefits, and, salary)
# 3      (The, worst, thing, is, loss, of, bonus, .)
# 4        (Lot, to, learn, ,, busy, ,, new, people)
#
#                                           con_tokens  \
# 0      (unstable, rota, and, early, morning, shifts)
# 1            (Management, are, lax, on, food, waste)
# 2                        (Nothing, to, say, so, far)
# 3  (New, management, created, silly, rules, and, ...
# 4                                       (Very, busy)
#
#                       pro_clean_token  \
# 0          [fast, grow, hard, worker]
# 1     [lot, shift, flexibility, hour]
# 2  [great, training, benefit, salary]
# 3           [bad, thing, loss, bonus]
# 4     [lot, learn, busy, new, people]
#
#                                      con_clean_token
# 0                  [unstable, early, morning, shift]
# 1                     [management, lax, food, waste]
# 2                                              [far]
# 3  [new, management, create, silly, rule, people,...
# 4                                             [busy]
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Pro comments Topic Modelling

# %%
#create our dictionary
#this assigns a number to each word
dictionary = corpora.Dictionary(df.pro_clean_token)

#number of times a word appears in the all of the data
corpus = [dictionary.doc2bow(text) for text in df.pro_clean_token]

# %%
# %%time
number_topics = 2

lda_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=number_topics, id2word=dictionary, passes=15)
# Out:
# Wall time: 4.64 s

# %%
topics = lda_model.print_topics(num_words = 5)

for topic in topics:
    print(topic)
# Out:
# (0, '0.080*"food" + 0.071*"free" + 0.052*"pay" + 0.038*"good" + 0.016*"coffee"')
# (1, '0.055*"good" + 0.055*"work" + 0.034*"great" + 0.027*"people" + 0.024*"team"')

# %%
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics = False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1947217888042132807863934477"></div>
# <script type="text/javascript">
#
# var ldavis_el1947217888042132807863934477_data = {"mdsDat": {"x": [0.1149051710963249, -0.1149051710963249], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [45.76461410522461, 54.235382080078125]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2"], "Freq": [176.0, 155.0, 118.0, 158.0, 35.0, 36.0, 75.0, 31.0, 35.0, 34.0, 27.0, 24.0, 29.0, 31.0, 43.0, 25.0, 20.0, 15.0, 44.0, 16.0, 20.0, 32.0, 113.0, 24.0, 10.0, 12.0, 15.0, 8.0, 11.0, 8.0, 34.6783561706543, 151.9280548095703, 170.71592712402344, 14.600330352783203, 30.69805145263672, 34.69136428833008, 23.38250732421875, 9.61466121673584, 112.0718765258789, 7.916677951812744, 7.899682998657227, 25.959623336791992, 6.2619781494140625, 18.738859176635742, 7.02536153793335, 15.598711967468262, 6.232378959655762, 5.4268798828125, 5.404842376708984, 6.17081880569458, 4.593624114990234, 31.30453872680664, 6.075859546661377, 4.555664539337158, 4.534131050109863, 5.286550045013428, 4.519759654998779, 4.518377780914307, 3.763334274291992, 4.514358043670654, 4.4817795753479, 25.511962890625, 12.812864303588867, 25.34717559814453, 5.138152599334717, 10.835996627807617, 29.093902587890625, 80.54975128173828, 7.564916133880615, 21.875125885009766, 22.163501739501953, 16.91985321044922, 22.424123764038086, 26.422218322753906, 16.291120529174805, 27.700794219970703, 10.00617504119873, 17.15099334716797, 15.174827575683594, 13.199219703674316, 18.041776657104492, 10.465460777282715, 34.592926025390625, 28.666547775268555, 24.18798065185547, 29.93364143371582, 10.774041175842285, 12.389659881591797, 9.899728775024414, 19.775970458984375, 9.867966651916504, 9.844611167907715, 8.172567367553711, 10.56512451171875, 8.114534378051758, 8.107948303222656, 8.104171752929688, 6.470947742462158, 7.279295921325684, 14.448617935180664, 6.420441627502441, 5.597209453582764, 5.582424163818359, 5.574632167816162, 5.56356143951416, 5.545941352844238, 4.743966102600098, 39.41179275512695, 22.066801071166992, 7.865682125091553, 4.7079315185546875, 4.699644088745117, 68.5417709350586, 140.2918243408203, 16.200273513793945, 38.837440490722656, 12.23952865600586, 21.734355926513672, 15.576992988586426, 85.42485046386719, 26.42138671875, 140.59805297851562, 60.8360710144043, 15.192456245422363, 41.89909362792969, 37.028411865234375, 41.642555236816406, 28.70283317565918, 16.775224685668945, 26.366952896118164, 22.059959411621094, 24.073596954345703, 26.128515243530273, 17.704814910888672, 16.556734085083008, 16.230131149291992], "Term": ["food", "free", "pay", "work", "break", "coffee", "people", "weekly", "place", "lunch", "drink", "discount", "manager", "friendly" ...

# %%
pyLDAvis.save_html(lda_display, 'Pro_Topics.html')

# %%
#cast topic probability back to dataframe
df['pro_topic_probability'] = df.pro_clean_token.map(lambda x: lda_model[dictionary.doc2bow(x)])

## retrieve the topic with the highest probability and place id as column value
df['pro_topic_id'] = df.pro_topic_probability.map(lambda x: max(x, key=itemgetter(1))[0])

df['pro_topic_label'] = df.pro_topic_id.apply(lambda x: 'Work environment' if x == 1 else 'Benefits')

df.head()
# Out:
#         date  star                                      subject  \
# 0 2019-11-04     5  Big dynamic company with many opportunities
# 1 2020-01-20     5                          Great Vacation Work
# 2 2020-01-20     4                                Great company
# 3 2020-01-16     3                            Something Helpful
# 4 2020-01-15     3                            One day probation
#
#                                       pros  \
# 0     Fast grows up if you are hard worker
# 1  Lots of shifts and flexibility of hours
# 2      Great training, benefits and salary
# 3        The worst thing is loss of bonus.
# 4           Lot to learn, busy, new people
#
#                                                 cons  \
# 0             unstable rota and early morning shifts
# 1                   Management are lax on food waste
# 2                              Nothing to say so far
# 3  New management created silly rules and people ...
# 4                                          Very busy
#
#                                               advice        location  \
# 0                                                NaN          London
# 1                                                NaN         Gatwick
# 2                                                NaN             NaN
# 3  Respect your staff more.They are amazing hard ...          London
# 4                       Be more patient with newbies   Palmers Green
#
#           clean_member_type  \
# 0              Team Leader
# 1              Team Member
# 2              Team Leader
# 3   Production Team Member
# 4            Kitchen Staff
#
#                                               tenure   employee_status  \
# 0  I have been working at Pret A Manger full-time...  Current Employee
# 1  I worked at Pret A Manger full-time for less t...   Former Employee
# 2     I have been working at Pret A Manger full-time  Current Employee
# 3  I worked at Pret A Manger full-time for more t...   Former Employee
# 4  I worked at Pret A Manger full-time for less t...   Former Employee
#
#      ...                        pro_clean_token  \
# 0    ...             [fast, grow, hard, worker]
# 1    ...        [lot, shift, flexibility, hour]
# 2    ...     [great, training, benefit, salary]
# 3    ...              [bad, thing, loss, bonus]
# 4    ...        [lot, learn, busy, new, people]
#
#                                      con_clean_token  \
# 0                  [unstable, early, morning, shift]
# 1                     [management, lax, food, waste]
# 2                                              [far]
# 3  [new, management, create, silly, rule, people,...
# 4                                             [busy]
#
#                             pro_topic   pro_topic_label  \
# 0   [(0, 0.54603934), (1, 0.4539607)]          Benefits
# 1    [(0, 0.4185669), (1, 0.5814331)]  Work environment
# 2   [(0, 0.12189384), (1, 0.8781062)]  Work environment
# 3  [(0, 0.11536618), (1, 0.88463384)]  Work environment
# 4   [(0, 0.08738959), (1, 0.9126104)]  Work environment
#
#                 pro_topic_probability pro_topic_id  \
# 0  [(0, 0.54555506), (1, 0.45444492)]            0
# 1  [(0, 0.41846275), (1, 0.58153725)]            1
# 2  [(0, 0.121889845), (1, 0.8781102)]            1
# 3   [(0, 0.11538027), (1, 0.8846197)]            1
# 4   [(0, 0.08738959), (1, 0.9126104)]            1
#
#                 con_topic_probability con_topic_id con_topic_label unique_id
# 0   [(0, 0.11103573), (1, 0.8889643)]            1         Culture         0
# 1   [(0, 0.19058193), (1, 0.8094181)]            1         Culture         1
# 2  [(0, 0.25403154), (1, 0.74596846)]            1         Culture         2
# 3  [(0, 0.25526074), (1, 0.74473923)]            1         Culture         3
# 4  [(0, 0.74890715), (1, 0.25109285)]            0            Work         4
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Con comments Topic Modelling

# %%
#create our dictionary
#this assigns a number to each word
con_dictionary = corpora.Dictionary(df.con_clean_token)

#number of times a word appears in the all of the data
corpus = [con_dictionary.doc2bow(text) for text in df.con_clean_token]

# %%
# %%time
number_topics = 2

con_lda_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=number_topics, id2word=con_dictionary, passes=15)
# Out:
# Wall time: 5.59 s

# %%
con_topics = con_lda_model.print_topics(num_words = 5)

for topic in con_topics:
    print(topic)
# Out:
# (0, '0.039*"work" + 0.023*"manager" + 0.015*"hard" + 0.015*"lot" + 0.013*"job"')
# (1, '0.036*"hour" + 0.030*"work" + 0.018*"time" + 0.017*"pay" + 0.015*"long"')

# %%
con_lda_display = pyLDAvis.gensim.prepare(con_lda_model, corpus, con_dictionary, sort_topics = False)
pyLDAvis.display(con_lda_display)
# Out:
# C:\Users\nirun\AppData\Local\Continuum\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1947217867368631762390102306"></div>
# <script type="text/javascript">
#
# var ldavis_el1947217867368631762390102306_data = {"mdsDat": {"x": [0.07543274760246275, -0.07543274760246275], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [49.42323303222656, 50.57676315307617]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2"], "Freq": [111.0, 43.0, 41.0, 47.0, 90.0, 35.0, 17.0, 28.0, 17.0, 25.0, 15.0, 38.0, 26.0, 14.0, 19.0, 13.0, 12.0, 12.0, 60.0, 12.0, 17.0, 52.0, 11.0, 12.0, 8.0, 69.0, 8.0, 8.0, 8.0, 8.0, 8.517967224121094, 13.877029418945312, 6.89762020111084, 13.014517784118652, 6.859930992126465, 6.067291736602783, 6.065592288970947, 6.823461532592773, 12.07378101348877, 5.275699138641357, 5.265918254852295, 5.251704216003418, 5.234619617462158, 7.455601692199707, 4.464218616485596, 4.460323333740234, 4.459850311279297, 4.455401420593262, 5.1890692710876465, 4.426760673522949, 4.393310070037842, 10.971358299255371, 4.388192653656006, 3.6539156436920166, 3.6419918537139893, 3.6398963928222656, 3.636366605758667, 3.6336615085601807, 3.626192569732666, 8.69549560546875, 36.83817672729492, 22.598373413085938, 24.658653259277344, 41.0208625793457, 15.440337181091309, 22.703937530517578, 30.960100173950195, 66.17475891113281, 42.619197845458984, 37.64854049682617, 13.687386512756348, 29.07892417907715, 31.231033325195312, 108.93765258789062, 33.69424819946289, 26.0531005859375, 31.651460647583008, 19.09247589111328, 23.339052200317383, 12.499977111816406, 28.219131469726562, 35.64120101928711, 13.647825241088867, 31.090444564819336, 16.239686965942383, 15.958940505981445, 18.60797119140625, 21.660409927368164, 14.998818397521973, 13.21657943725586, 43.23894500732422, 14.855667114257812, 11.725467681884766, 11.724227905273438, 17.1693058013916, 16.291288375854492, 8.49119758605957, 8.471365928649902, 6.884523868560791, 8.385026931762695, 104.38867950439453, 6.841134548187256, 8.324633598327637, 6.04511833190918, 10.571211814880371, 7.535125732421875, 5.260408878326416, 6.752954483032227, 7.477780342102051, 8.21711254119873, 5.22584867477417, 5.211788654327393, 4.454668998718262, 5.19423246383667, 4.451511383056641, 4.451216697692871, 4.4456000328063965, 5.918828010559082, 5.176153182983398, 4.4270806312561035, 17.65677261352539, 5.878640651702881, 30.715864181518555, 9.333179473876953, 5.142300605773926, 10.435805320739746, 48.10861587524414, 7.06965446472168, 18.638233184814453, 50.858314514160156, 12.770633697509766, 14.104890823364258, 7.623533725738525, 86.6695556 ...

# %%
pyLDAvis.save_html(lda_display, 'Con_Topics.html')

# %%
#cast topic probability back to dataframe
df['con_topic_probability'] = df.con_clean_token.map(lambda x: con_lda_model[con_dictionary.doc2bow(x)])

## retrieve the topic with the highest probability and place id as column value
df['con_topic_id'] = df.con_topic_probability.map(lambda x: max(x, key=itemgetter(1))[0])

df['con_topic_label'] = df.con_topic_id.apply(lambda x: 'Culture' if x == 1 else 'Work')

df.head()
# Out:
#         date  star                                      subject  \
# 0 2019-11-04     5  Big dynamic company with many opportunities
# 1 2020-01-20     5                          Great Vacation Work
# 2 2020-01-20     4                                Great company
# 3 2020-01-16     3                            Something Helpful
# 4 2020-01-15     3                            One day probation
#
#                                       pros  \
# 0     Fast grows up if you are hard worker
# 1  Lots of shifts and flexibility of hours
# 2      Great training, benefits and salary
# 3        The worst thing is loss of bonus.
# 4           Lot to learn, busy, new people
#
#                                                 cons  \
# 0             unstable rota and early morning shifts
# 1                   Management are lax on food waste
# 2                              Nothing to say so far
# 3  New management created silly rules and people ...
# 4                                          Very busy
#
#                                               advice        location  \
# 0                                                NaN          London
# 1                                                NaN         Gatwick
# 2                                                NaN             NaN
# 3  Respect your staff more.They are amazing hard ...          London
# 4                       Be more patient with newbies   Palmers Green
#
#           clean_member_type  \
# 0              Team Leader
# 1              Team Member
# 2              Team Leader
# 3   Production Team Member
# 4            Kitchen Staff
#
#                                               tenure   employee_status  \
# 0  I have been working at Pret A Manger full-time...  Current Employee
# 1  I worked at Pret A Manger full-time for less t...   Former Employee
# 2     I have been working at Pret A Manger full-time  Current Employee
# 3  I worked at Pret A Manger full-time for more t...   Former Employee
# 4  I worked at Pret A Manger full-time for less t...   Former Employee
#
#      ...                        pro_clean_token  \
# 0    ...             [fast, grow, hard, worker]
# 1    ...        [lot, shift, flexibility, hour]
# 2    ...     [great, training, benefit, salary]
# 3    ...              [bad, thing, loss, bonus]
# 4    ...        [lot, learn, busy, new, people]
#
#                                      con_clean_token  \
# 0                  [unstable, early, morning, shift]
# 1                     [management, lax, food, waste]
# 2                                              [far]
# 3  [new, management, create, silly, rule, people,...
# 4                                             [busy]
#
#                             pro_topic   pro_topic_label  \
# 0   [(0, 0.54603934), (1, 0.4539607)]          Benefits
# 1    [(0, 0.4185669), (1, 0.5814331)]  Work environment
# 2   [(0, 0.12189384), (1, 0.8781062)]  Work environment
# 3  [(0, 0.11536618), (1, 0.88463384)]  Work environment
# 4   [(0, 0.08738959), (1, 0.9126104)]  Work environment
#
#                 pro_topic_probability pro_topic_id  \
# 0  [(0, 0.54555506), (1, 0.45444492)]            0
# 1  [(0, 0.41846275), (1, 0.58153725)]            1
# 2  [(0, 0.121889845), (1, 0.8781102)]            1
# 3   [(0, 0.11538027), (1, 0.8846197)]            1
# 4   [(0, 0.08738959), (1, 0.9126104)]            1
#
#                 con_topic_probability con_topic_id con_topic_label unique_id
# 0   [(0, 0.8649142), (1, 0.13508579)]            0            Work         0
# 1  [(0, 0.118999586), (1, 0.8810004)]            1         Culture         1
# 2  [(0, 0.74737763), (1, 0.25262237)]            0            Work         2
# 3   [(0, 0.24565211), (1, 0.7543479)]            1         Culture         3
# 4    [(0, 0.7417878), (1, 0.2582122)]            0            Work         4
#
# [5 rows x 31 columns]

# %% [markdown]
# # Pro Comments Word Counts

# %%
df['unique_id'] = df.index

pro_df = df[['unique_id','date', 'pro_topic_label' ,'star_group', 'pro_clean_token']]

pro_df.head()
# Out:
#    unique_id       date   pro_topic_label star_group  \
# 0          0 2019-11-04          Benefits   Positive
# 1          1 2020-01-20  Work environment   Positive
# 2          2 2020-01-20  Work environment   Positive
# 3          3 2020-01-16  Work environment    Neutral
# 4          4 2020-01-15  Work environment    Neutral
#
#                       pro_clean_token
# 0          [fast, grow, hard, worker]
# 1     [lot, shift, flexibility, hour]
# 2  [great, training, benefit, salary]
# 3           [bad, thing, loss, bonus]
# 4     [lot, learn, busy, new, people]

# %%
pro_df['pro_clean_token'] = [','.join(map(str, l)) for l in pro_df['pro_clean_token']]

pro_df.head()
# Out:
# C:\Users\nirun\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    unique_id       date   pro_topic_label star_group  \
# 0          0 2019-11-04          Benefits   Positive
# 1          1 2020-01-20  Work environment   Positive
# 2          2 2020-01-20  Work environment   Positive
# 3          3 2020-01-16  Work environment    Neutral
# 4          4 2020-01-15  Work environment    Neutral
#
#                  pro_clean_token
# 0          fast,grow,hard,worker
# 1     lot,shift,flexibility,hour
# 2  great,training,benefit,salary
# 3           bad,thing,loss,bonus
# 4      lot,learn,busy,new,people

# %%
# Set up empty df
pro_split_df = pd.DataFrame()

for i, row in pro_df.iterrows():
    
    # Create a list of the pro words
    pro_list = row['pro_clean_token'].split(',')
    
    # Make df
    pro_iter_df = pd.DataFrame(pro_list, columns = ['pro_clean_token'])
    
    # Populate extra columns
    pro_iter_df['date'] = row['date']
    pro_iter_df['star_group'] = row['star_group']
    pro_iter_df['unique_id'] = row['unique_id']
    pro_iter_df['pro_topic_label'] = row['pro_topic_label']
    
  
    pro_split_df = pro_split_df.append(pro_iter_df, ignore_index = True)
    
print(pro_split_df.shape)
pro_split_df.head()
# Out:
# (4678, 5)
#   pro_clean_token       date star_group  unique_id   pro_topic_label
# 0            fast 2019-11-04   Positive          0          Benefits
# 1            grow 2019-11-04   Positive          0          Benefits
# 2            hard 2019-11-04   Positive          0          Benefits
# 3          worker 2019-11-04   Positive          0          Benefits
# 4             lot 2020-01-20   Positive          1  Work environment

# %%
pro_split_df.to_csv('Pros_word_count.csv', index = False)

# %% [markdown]
# # Pro Comments Word Counts

# %%
con_df = df[['unique_id','date', 'con_topic_label' ,'star_group', 'con_clean_token']]

con_df['con_clean_token'] = [','.join(map(str, l)) for l in con_df['con_clean_token']]

con_df.head()
# Out:
# C:\Users\nirun\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    unique_id       date con_topic_label star_group  \
# 0          0 2019-11-04            Work   Positive
# 1          1 2020-01-20         Culture   Positive
# 2          2 2020-01-20            Work   Positive
# 3          3 2020-01-16         Culture    Neutral
# 4          4 2020-01-15            Work    Neutral
#
#                                      con_clean_token
# 0                       unstable,early,morning,shift
# 1                          management,lax,food,waste
# 2                                                far
# 3  new,management,create,silly,rule,people,work,m...
# 4                                               busy

# %%
# Set up empty df
con_split_df = pd.DataFrame()

for i, row in con_df.iterrows():
    
    # Create a list of the pro words
    con_list = row['con_clean_token'].split(',')
    
    # Make df
    con_iter_df = pd.DataFrame(con_list, columns = ['con_clean_token'])
    
    # Populate extra columns
    con_iter_df['date'] = row['date']
    con_iter_df['star_group'] = row['star_group']
    con_iter_df['unique_id'] = row['unique_id']
    con_iter_df['con_topic_label'] = row['con_topic_label']
    
  
    con_split_df = con_split_df.append(con_iter_df, ignore_index = True)
    
print(con_split_df.shape)
con_split_df.head()
# Out:
# (5704, 5)
#   con_clean_token       date star_group  unique_id con_topic_label
# 0        unstable 2019-11-04   Positive          0            Work
# 1           early 2019-11-04   Positive          0            Work
# 2         morning 2019-11-04   Positive          0            Work
# 3           shift 2019-11-04   Positive          0            Work
# 4      management 2020-01-20   Positive          1         Culture

# %%
con_split_df.to_csv('Con_word_count.csv', index = False)
